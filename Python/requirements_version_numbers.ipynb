# %%
deps='''aiohappyeyeballs==2.6.1
aiohttp==3.13.5
aiosignal==1.4.0
alembic==1.18.4
annotated-doc==0.0.4
annotated-types==0.7.0
anyio==4.13.0
attrs==26.1.0
beautifulsoup4==4.14.3
blinker==1.9.0
blis==1.3.3
cachetools==7.0.5
catalogue==2.0.10
certifi==2026.2.25
cffi==2.0.0
charset-normalizer==3.4.7
click==8.3.2
cloudpathlib==0.23.0
cloudpickle==3.1.2
confection==1.3.3
contourpy==1.3.3
cryptography==46.0.7
cycler==0.12.1
cymem==2.0.13
databricks-sdk==0.102.0
docker==7.1.0
fastapi==0.136.0
Flask==3.1.3
flask-cors==6.0.2
fonttools==4.62.1
fr_core_news_sm @ https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-3.8.0/fr_core_news_sm-3.8.0-py3-none-any.whl#sha256=7d6ad14cd5078e53147bfbf70fb9d433c6a3865b695fda2657140bbc59a27e29
frozenlist==1.8.0
gitdb==4.0.12
GitPython==3.1.46
google-auth==2.49.2
graphene==3.4.3
graphql-core==3.2.8
graphql-relay==3.2.0
greenlet==3.4.0
gunicorn==25.3.0
h11==0.16.0
httpcore==1.0.9
httptools==0.7.1
httpx==0.28.1
huey==2.6.0
idna==3.11
importlib_metadata==8.7.1
itsdangerous==2.2.0
Jinja2==3.1.6
joblib==1.5.3
kiwisolver==1.5.0
Mako==1.3.11
markdown-it-py==4.0.0
MarkupSafe==3.0.3
matplotlib==3.10.8
mdurl==0.1.2
mlflow==3.11.1
mlflow-skinny==3.11.1
mlflow-tracing==3.11.1
multidict==6.7.1
murmurhash==1.0.15
nltk==3.9.4
numpy==2.4.4
opentelemetry-api==1.41.0
opentelemetry-proto==1.41.0
opentelemetry-sdk==1.41.0
opentelemetry-semantic-conventions==0.62b0
packaging==26.1
pandas==2.3.3
pillow==12.2.0
preshed==3.0.13
prettytable==3.17.0
propcache==0.4.1
protobuf==6.33.6
pyarrow==23.0.1
pyasn1==0.6.3
pyasn1_modules==0.4.2
pycparser==3.0
pydantic==2.13.1
pydantic_core==2.46.1
Pygments==2.20.0
pyparsing==3.3.2
python-dateutil==2.9.0.post0
python-dotenv==1.2.2
pytz==2026.1.post1
PyYAML==6.0.3
regex==2026.4.4
requests==2.33.1
rich==15.0.0
scikit-learn==1.8.0
scipy==1.17.1
setuptools==82.0.1
shellingham==1.5.4
six==1.17.0
skops==0.13.0
smart_open==7.6.0
smmap==5.0.3
soupsieve==2.8.3
spacy==3.8.14
spacy-legacy==3.0.12
spacy-loggers==1.0.5
SQLAlchemy==2.0.49
sqlparse==0.5.5
srsly==2.5.3
starlette==1.0.0
thinc==8.3.13
threadpoolctl==3.6.0
tqdm==4.67.3
typer==0.24.1
typing-inspection==0.4.2
typing_extensions==4.15.0
tzdata==2026.1
Unidecode==1.4.0
urllib3==2.6.3
uvicorn==0.44.0
uvloop==0.22.1
wasabi==1.1.3
watchfiles==1.1.1
wcwidth==0.6.0
weasel==1.0.0
websockets==16.0
Werkzeug==3.1.8
wrapt==2.1.2
yarl==1.23.0
zipp==3.23.1
'''

# %%
reqs='''fastapi
uvicorn[standard]
beautifulsoup4
joblib
mlflow
pandas
nltk
scipy
spacy
Unidecode
scikit-learn
'''

# %%
reqs_list=reqs.splitlines()
reqs_list
# Out:
# ['fastapi',
#  'uvicorn[standard]',
#  'beautifulsoup4',
#  'joblib',
#  'mlflow',
#  'pandas',
#  'nltk',
#  'scipy',
#  'spacy',
#  'Unidecode',
#  'scikit-learn']

# %%
reqs_v=[]
for dep in deps.splitlines():
    dep_name=dep.split('=')[0]
    if dep_name in reqs_list:
        reqs_v.append(dep)
reqs_v
# Out:
# ['beautifulsoup4==4.14.3',
#  'fastapi==0.136.0',
#  'joblib==1.5.3',
#  'mlflow==3.11.1',
#  'nltk==3.9.4',
#  'pandas==2.3.3',
#  'scikit-learn==1.8.0',
#  'scipy==1.17.1',
#  'spacy==3.8.14',
#  'Unidecode==1.4.0']

# %%
len(reqs_v),len(reqs_list)
# Out:
# (10, 11)

# %%
sorted(reqs_v)
# Out:
# ['Unidecode==1.4.0',
#  'beautifulsoup4==4.14.3',
#  'fastapi==0.136.0',
#  'joblib==1.5.3',
#  'mlflow==3.11.1',
#  'nltk==3.9.4',
#  'pandas==2.3.3',
#  'scikit-learn==1.8.0',
#  'scipy==1.17.1',
#  'spacy==3.8.14']

# %%
sorted(reqs_list)
# Out:
# ['Unidecode',
#  'beautifulsoup4',
#  'fastapi',
#  'joblib',
#  'mlflow',
#  'nltk',
#  'pandas',
#  'scikit-learn',
#  'scipy',
#  'spacy',
#  'uvicorn[standard]']

# %%
reqs_v.append("uvicorn[standard]==0.44.0")

# %%
print('\n'.join(reqs_v))
# Out:
# beautifulsoup4==4.14.3
# fastapi==0.136.0
# joblib==1.5.3
# mlflow==3.11.1
# nltk==3.9.4
# pandas==2.3.3
# scikit-learn==1.8.0
# scipy==1.17.1
# spacy==3.8.14
# Unidecode==1.4.0
# uvicorn[standard]==0.44.0
